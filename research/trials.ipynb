# %%
import gdown

# %%
url="https://drive.google.com/file/d/1tKknQJ4-0rahmbkq4cVP_b_C3zr4Kc1F/view?usp=sharing"

# %%
file_id= url.split('/')[-2]

# %%
file_id
# Out:
# '1tKknQJ4-0rahmbkq4cVP_b_C3zr4Kc1F'

# %%
from gdown.download import download
prefix = 'https://drive.google.com/uc?id='
download(f"{prefix}{file_id}", "kidney-city-scan-data.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1tKknQJ4-0rahmbkq4cVP_b_C3zr4Kc1F
# From (redirected): https://drive.google.com/uc?id=1tKknQJ4-0rahmbkq4cVP_b_C3zr4Kc1F&confirm=t&uuid=f62e2f2e-0c22-4e0e-8db9-b98341299476
# To: c:\Users\abhin\Desktop\Mlops\Deep-Learning-Kidney-Tumor-Classification-\research\kidney-city-scan-data.zip
# 100%|██████████| 941M/941M [00:21<00:00, 43.6MB/s]
# 'kidney-city-scan-data.zip'
